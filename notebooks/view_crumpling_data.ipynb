# %%
import numpy as np
import scipy as sp
import scipy.io as io

import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib as mpl
import seaborn as sns

# %%
# mat = io.loadmat("H1_binary.mat")

mat = io.loadmat("4Eleni/Creases17.mat")

print(mat.keys())

plt.imshow(mat['ridges'], cmap="Greys")
plt.show()

plt.imshow(mat['valleys'], cmap="Greys")
plt.show()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'ridges', 'valleys'])

# %%
import scipy.ndimage.morphology as morph

plt.imshow(mat['ridgesH1'], cmap="Greys")
plt.show()

data = mat['ridgesH1']
for i in range(10):
    data = morph.binary_dilation(data)
    
    plt.imshow(data, cmap="Greys")
    plt.show()

# %%
import os
import matplotlib.pyplot as plt
from skimage.data import data_dir
from skimage.util import img_as_ubyte
from skimage import io

orig_phantom = mat['ridges']

fig, ax = plt.subplots()
ax.imshow(orig_phantom, cmap=plt.cm.gray)

plt.show()

def plot_comparison(original, filtered, filter_name):

    fig, ax1 = plt.subplots(1,1)
  
    ax1.imshow(filtered, cmap=plt.cm.gray)
    ax1.axis('off')
    ax1.set_adjustable('box-forced')
    
    plt.show()

from skimage.morphology import erosion, dilation, opening, closing, white_tophat
from skimage.morphology import black_tophat, skeletonize, convex_hull_image
from skimage.morphology import disk


dilated = orig_phantom
for i in range(20):
    selem = disk(4)

    dilated = dilation(dilated, selem)
    plot_comparison(orig_phantom, dilated, 'dilation')
